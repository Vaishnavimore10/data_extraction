# %%
import pandas as pd

# %%
df=pd.read_csv('dataset.vereo.csv')

# %%
df
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
df.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %%
df4=df[['Product Name', 'Sales','shipping date (DateOrders)']]

# %%
df4[df4['Product Name'].str.contains('Nike')].min()
# Out:
# Product Name                  Nike Dri-FIT Crew Sock 6 Pack
# Sales                                                    22
# shipping date (DateOrders)                 01-01-2016 00:32
# dtype: object

# %%
df3=df[['Product Name', 'Product Price','Order Item Discount Rate']]

# %%
df3
# Out:
#                                      Product Name  Product Price  \
# 0                                    Smart watch      327.750000
# 1                                    Smart watch      327.750000
# 2                                    Smart watch      327.750000
# 3                                    Smart watch      327.750000
# 4                                    Smart watch      327.750000
# ...                                           ...            ...
# 180514  Field & Stream Sportsman 16 Gun Fire Safe     399.980011
# 180515  Field & Stream Sportsman 16 Gun Fire Safe     399.980011
# 180516  Field & Stream Sportsman 16 Gun Fire Safe     399.980011
# 180517  Field & Stream Sportsman 16 Gun Fire Safe     399.980011
# 180518  Field & Stream Sportsman 16 Gun Fire Safe     399.980011
#
#         Order Item Discount Rate
# 0                           0.04
# 1                           0.05
# 2                           0.06
# 3                           0.07
# ...

# %%
g=df3['Order Item Discount Rate'].idxmax()

# %%
g
# Out:
# 13

# %%
df3.loc[13]
# Out:
# Product Name                Smart watch
# Product Price                     327.75
# Order Item Discount Rate            0.25
# Name: 13, dtype: object

# %%
df1=df[['Order Country','Order City','Order Status']]

# %%
df1
# Out:
#        Order Country  Order City     Order Status
# 0          Indonesia      Bekasi         COMPLETE
# 1              India     Bikaner          PENDING
# 2              India     Bikaner           CLOSED
# 3          Australia  Townsville         COMPLETE
# 4          Australia  Townsville  PENDING_PAYMENT
# ...              ...         ...              ...
# 180514         China    Shanghái           CLOSED
# 180515         Japón    Hirakata         COMPLETE
# 180516     Australia    Adelaide          PENDING
# 180517     Australia    Adelaide  PENDING_PAYMENT
# 180518         India   Nagercoil  PENDING_PAYMENT
#
# [180519 rows x 3 columns]

# %%
a=df1[df1['Order Country'].str.contains('India')]

# %%
b=a[a['Order Status'].str.contains('PENDING')]

# %%
b.pivot_table(index = ['Order City'], aggfunc ='size')
# Out:
# Order City
# Agra             24
# Ajmer            45
# Akola             6
# Aligarh          12
# Allahabad         2
#                  ..
# Vadodara         13
# Varanasi          4
# Vijayawada       13
# Visakhapatnam    25
# Warangal         13
# Length: 128, dtype: int64

# %%
df2=df[['Customer Country','Order Status']]

# %%
df2
# Out:
#        Customer Country     Order Status
# 0           Puerto Rico         COMPLETE
# 1           Puerto Rico          PENDING
# 2               EE. UU.           CLOSED
# 3               EE. UU.         COMPLETE
# 4           Puerto Rico  PENDING_PAYMENT
# ...                 ...              ...
# 180514          EE. UU.           CLOSED
# 180515          EE. UU.         COMPLETE
# 180516          EE. UU.          PENDING
# 180517      Puerto Rico  PENDING_PAYMENT
# 180518      Puerto Rico  PENDING_PAYMENT
#
# [180519 rows x 2 columns]

# %%
c
# Out:
#        Customer Country     Order Status
# 10          Puerto Rico  SUSPECTED_FRAUD
# 24              EE. UU.  SUSPECTED_FRAUD
# 183             EE. UU.  SUSPECTED_FRAUD
# 184             EE. UU.  SUSPECTED_FRAUD
# 185             EE. UU.  SUSPECTED_FRAUD
# ...                 ...              ...
# 180274      Puerto Rico  SUSPECTED_FRAUD
# 180309          EE. UU.  SUSPECTED_FRAUD
# 180352          EE. UU.  SUSPECTED_FRAUD
# 180406      Puerto Rico  SUSPECTED_FRAUD
# 180490          EE. UU.  SUSPECTED_FRAUD
#
# [4062 rows x 2 columns]

# %%
c.pivot_table(index = ['Customer Country'], aggfunc ='size')
# Out:
# Customer Country
# EE. UU.        2413
# Puerto Rico    1649
# dtype: int64

# %%
df5=df[['Days for shipping (real)', 'Days for shipment (scheduled)', 'Order Status']]

# %%
df5
# Out:
#         Days for shipping (real)  Days for shipment (scheduled)  \
# 0                              3                              4
# 1                              5                              4
# 2                              4                              4
# 3                              3                              4
# 4                              2                              4
# ...                          ...                            ...
# 180514                         4                              4
# 180515                         3                              2
# 180516                         5                              4
# 180517                         3                              4
# 180518                         4                              4
#
#            Order Status
# 0              COMPLETE
# 1               PENDING
# 2                CLOSED
# 3              COMPLETE
# 4       PENDING_PAYMENT
# ...                 ...
# ...

# %%
x=df5[df5['Order Status'].str.contains('COMPLETE')]

# %%
x
# Out:
#         Days for shipping (real)  Days for shipment (scheduled) Order Status
# 0                              3                              4     COMPLETE
# 3                              3                              4     COMPLETE
# 6                              2                              1     COMPLETE
# 13                             2                              1     COMPLETE
# 15                             2                              1     COMPLETE
# ...                          ...                            ...          ...
# 180500                         3                              4     COMPLETE
# 180505                         2                              4     COMPLETE
# 180508                         4                              2     COMPLETE
# 180512                         6                              4     COMPLETE
# 180515                         3                              2     COMPLETE
#
# [59491 rows x 3 columns]

# %%
import numpy as np

# %%
l=np.where(x['Days for shipping (real)'] > x['Days for shipment (scheduled)'], 'True', 'False')

# %%
l
# Out:
# array(['False', 'False', 'True', ..., 'True', 'True', 'True'], dtype='<U5')

# %%
m= pd.DataFrame(l, columns = ['Column_A'])

# %%
m=m[m['Column_A'].str.contains('True')]

# %%
m
# Out:
#       Column_A
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# ...        ...
# 59480     True
# 59485     True
# 59488     True
# 59489     True
# 59490     True
#
# [34199 rows x 1 columns]
